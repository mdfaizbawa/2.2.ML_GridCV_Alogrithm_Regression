# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
independent=sd.fit_transform(independent)

# %%
import pickle
filename="standard.pkl"
pickle.dump(sd,open(filename,'wb'))

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'splitter':['best', 'random'],'max_features':['sqrt', 'log2']}

# %%
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best parameter after tuning
resul=grid.cv_results_
print("Thte R_Score value for best parameter:{}".format(grid.best_params_))
# Out:
# Thte R_Score value for best parameter:{'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
#Table
table=pd.DataFrame.from_dict(resul)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.012383      0.004755         0.001687        0.001387
# 1        0.003528      0.002553         0.006003        0.003550
# 2        0.004689      0.000286         0.001801        0.000400
# 3        0.003073      0.000310         0.001702        0.000956
# 4        0.004253      0.004319         0.001212        0.001174
# 5        0.003454      0.000750         0.001741        0.000389
# 6        0.004611      0.000563         0.001626        0.000503
# 7        0.001402      0.001747         0.003742        0.002633
# 8        0.017582      0.006182         0.004412        0.004642
# 9        0.014112      0.000929         0.002411        0.002735
# 10       0.024493      0.003796         0.001600        0.001019
# 11       0.012999      0.002795         0.001174        0.001556
# 12       0.003093      0.001604         0.000775        0.001549
# 13       0.004012      0.004913         0.004420        0.004595
# 14       0.007954      0.004058         0.002240        0.002744
# 15       0.004481      0.002240         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.697396
# 1   {'criterion': 'squared_error', 'max_features':...           0.730051
# 2   {'criterion': 'squared_error', 'max_features':...           0.736983
# 3   {'criterion': 'squared_error', 'max_features':...           0.567679
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.764875
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.673406
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.715944
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.689236
# 8   {'criterion': 'absolute_error', 'max_features'...           0.730761
# 9   {'criterion': 'absolute_error', 'max_features'...           0.672963
# 10  {'criterion': 'absolute_error', 'max_features'...           0.722524
# 11  {'criterion': 'absolute_error', 'max_features'...           0.749343
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.674035
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.631723
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.744559
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.685565
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.618700           0.721380           0.649920
# 1            0.514815           0.717873           0.643777
# 2            0.659231           0.647894           0.601861
# 3            0.580123           0.616762           0.692782
# 4            0.713283           0.732158           0.712752
# 5            0.527852           0.644576           0.661792
# 6            0.710914           0.623698           0.710324
# 7            0.484077           0.677385           0.656535
# 8            0.606109           0.499152           0.694732
# 9            0.636254           0.650081           0.604613
# 10           0.597789           0.719027           0.633262
# 11           0.630890           0.776453           0.664043
# 12           0.548001           0.706497           0.689156
# 13           0.520189           0.643572           0.653046
# 14           0.632941           0.712376           0.409678
# 15           0.627892           0.688461           0.691018
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.643689         0.666217        0.037539                8
# 1            0.619905         0.645284        0.077618               10
# 2            0.743444         0.677883        0.054438                6
# 3            0.667718         0.625013        0.048553               14
# 4            0.737078         0.732029        0.019118                1
# 5            0.619650         0.625455        0.052049               13
# 6            0.725645         0.697305        0.037211                3
# 7            0.624690         0.626385        0.074451               12
# 8            0.574705         0.621092        0.083302               15
# 9            0.684064         0.649595        0.028056                9
# 10           0.729305         0.680382        0.054230                5
# 11           0.688208         0.701787        0.053799                2
# 12           0.714348         0.666407        0.060830                7
# 13           0.630083         0.615723        0.048492               16
# 14           0.716451         0.643201        0.122526               11
# 15           0.748874         0.688362        0.038297                4

# %%
y_predt=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,y_predt)
r_score
# Out:
# 0.998667156135576

# %%
import pickle
filename="final_model_DR.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 19
# BMI: 33.777
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
preinput=sd.transform([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
preinput
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.43876426,  0.51076941, -0.90861367, -1.0105187 , -0.5074631 ]])

# %%
loaded_model=pickle.load(open("final_model_DR.sav",'rb'))

# %%
result=loaded_model.predict(preinput)
result
# Out:
# array([1748.774])
