# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
independent=sd.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid={'n_estimators':[10,50,100],'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'max_features':['sqrt', 'log2']}

# %%
grid=GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
#print best parameter after tuning
result=grid.cv_results_
print("Thte R_Score value for best parameter:{}".format(grid.best_params_))
# Out:
# Thte R_Score value for best parameter:{'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
#Table
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.039637      0.002031         0.004181        0.000381
# 1        0.142376      0.007598         0.007506        0.001027
# 2        0.282082      0.007845         0.015925        0.003899
# 3        0.030152      0.004218         0.002933        0.000496
# 4        0.141632      0.005394         0.008186        0.001381
# 5        0.290488      0.012212         0.009175        0.002964
# 6        0.043131      0.012749         0.004115        0.001547
# 7        0.143898      0.008758         0.005357        0.003318
# 8        0.278113      0.018569         0.009678        0.001188
# 9        0.031935      0.007590         0.003124        0.002573
# 10       0.154493      0.020697         0.006927        0.003684
# 11       0.277354      0.015327         0.013775        0.004690
# 12       0.111788      0.008124         0.003650        0.000859
# 13       0.474681      0.013493         0.004531        0.004977
# 14       0.933462      0.032258         0.011943        0.002119
# 15       0.100890      0.006176         0.000901        0.001116
# 16       0.496781      0.027634         0.006332        0.001053
# 17       0.921535      0.027304         0.009490        0.003216
# 18       0.029355      0.004190         0.003920        0.003730
# 19       0.137788      0.004754         0.006697        0.003298
# 20       0.280615      0.010142         0.011978        0.002406
# 21       0.030469      0.001995         0.000617        0.001234
# 22       0.152404      0.004084         0.006049        0.003335
# 23       0.280904      0.009961         0.012165        0.000544
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                 50
# 2    squared_error               sqrt                100
# 3    squared_error               log2                 10
# 4    squared_error               log2                 50
# 5    squared_error               log2                100
# 6     friedman_mse               sqrt                 10
# 7     friedman_mse               sqrt                 50
# 8     friedman_mse               sqrt                100
# 9     friedman_mse               log2                 10
# 10    friedman_mse               log2                 50
# 11    friedman_mse               log2                100
# 12  absolute_error               sqrt                 10
# 13  absolute_error               sqrt                 50
# 14  absolute_error               sqrt                100
# 15  absolute_error               log2                 10
# 16  absolute_error               log2                 50
# 17  absolute_error               log2                100
# 18         poisson               sqrt                 10
# 19         poisson               sqrt                 50
# 20         poisson               sqrt                100
# 21         poisson               log2                 10
# 22         poisson               log2                 50
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.826043
# 1   {'criterion': 'squared_error', 'max_features':...           0.855964
# 2   {'criterion': 'squared_error', 'max_features':...           0.859691
# 3   {'criterion': 'squared_error', 'max_features':...           0.837463
# 4   {'criterion': 'squared_error', 'max_features':...           0.858365
# 5   {'criterion': 'squared_error', 'max_features':...           0.855678
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.837034
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.857498
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.861414
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.838378
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.852789
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.860637
# 12  {'criterion': 'absolute_error', 'max_features'...           0.844594
# 13  {'criterion': 'absolute_error', 'max_features'...           0.858158
# 14  {'criterion': 'absolute_error', 'max_features'...           0.858569
# 15  {'criterion': 'absolute_error', 'max_features'...           0.855978
# 16  {'criterion': 'absolute_error', 'max_features'...           0.858823
# 17  {'criterion': 'absolute_error', 'max_features'...           0.860758
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.839147
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.852341
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859162
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.831451
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.853013
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.861254
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.780791           0.851279           0.811953
# 1            0.777671           0.860070           0.829071
# 2            0.777557           0.863624           0.824651
# 3            0.768430           0.856826           0.819126
# 4            0.767839           0.856206           0.827978
# 5            0.782051           0.859398           0.826827
# 6            0.757457           0.850161           0.823167
# 7            0.781647           0.851590           0.826007
# 8            0.775150           0.863315           0.830081
# 9            0.777733           0.836358           0.812560
# 10           0.774114           0.861793           0.824754
# 11           0.782584           0.857169           0.830194
# 12           0.763866           0.841802           0.814492
# 13           0.781591           0.860078           0.825662
# 14           0.779169           0.860642           0.826138
# 15           0.772769           0.853410           0.806433
# 16           0.778542           0.855686           0.820938
# 17           0.782036           0.856378           0.827517
# 18           0.758612           0.854928           0.815759
# 19           0.775929           0.857598           0.828537
# 20           0.780802           0.864537           0.828622
# 21           0.762963           0.850894           0.809904
# 22           0.781696           0.847786           0.827447
# 23           0.779545           0.860712           0.828150
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.829175         0.819848        0.023242               20
# 1            0.837547         0.832065        0.029506               10
# 2            0.835121         0.832129        0.030966                9
# 3            0.836445         0.823658        0.030083               18
# 4            0.840413         0.830160        0.033069               15
# 5            0.842511         0.833293        0.028054                8
# 6            0.816246         0.816813        0.031890               23
# 7            0.840249         0.831398        0.027098               11
# 8            0.840281         0.834048        0.032028                4
# 9            0.819772         0.816960        0.021914               22
# 10           0.840902         0.830870        0.030971               12
# 11           0.842117         0.834540        0.028174                2
# 12           0.793053         0.811561        0.030436               24
# 13           0.844473         0.833992        0.028947                5
# 14           0.843462         0.833596        0.029901                7
# 15           0.833848         0.824487        0.031358               17
# 16           0.838857         0.830569        0.029317               13
# 17           0.845591         0.834456        0.028609                3
# 18           0.822134         0.818116        0.032741               21
# 19           0.836494         0.830180        0.029081               14
# 20           0.841937         0.835012        0.029941                1
# 21           0.848055         0.820653        0.032328               19
# 22           0.839378         0.829864        0.025588               16
# 23           0.838581         0.833648        0.029921                6

# %%
y_predt=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,y_predt)
r_score
# Out:
# 0.9766256974196408
