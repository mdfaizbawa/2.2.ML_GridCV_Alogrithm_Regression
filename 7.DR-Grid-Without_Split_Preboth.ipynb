# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
independent=sd.fit_transform(independent)

# %%
sdy=StandardScaler()
dependent=sdy.fit_transform(dependent)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'splitter':['best', 'random'],'max_features':['sqrt', 'log2']}

# %%
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 20 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1377, in fit
#     super()._fit(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 269, in _fit
#     raise ValueError(
# ValueError: Some value(s) of y are negative which is not allowed for Poisson regression.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.71078633 0.6744085  0.68456298 0.6482416  0.67279038 0.66091078
#  0.67431365 0.61084685 0.70753087 0.62993423 0.68135552 0.65180181
#         nan        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best parameter after tuning
resul=grid.cv_results_
print("Thte R_Score value for best parameter:{}".format(grid.best_params_))
# Out:
# Thte R_Score value for best parameter:{'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
#Table
table=pd.DataFrame.from_dict(resul)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002364      0.004729         0.002144        0.004289
# 1        0.002433      0.003937         0.000000        0.000000
# 2        0.004204      0.004291         0.000506        0.001012
# 3        0.003644      0.004516         0.000426        0.000851
# 4        0.002933      0.002797         0.001304        0.002607
# 5        0.000000      0.000000         0.005139        0.004233
# 6        0.004888      0.004038         0.001017        0.001000
# 7        0.003162      0.003880         0.000153        0.000306
# 8        0.016566      0.004814         0.000000        0.000000
# 9        0.012551      0.000098         0.001617        0.003234
# 10       0.020756      0.000000         0.000000        0.000000
# 11       0.015419      0.004078         0.000000        0.000000
# 12       0.000000      0.000000         0.000000        0.000000
# 13       0.000732      0.001198         0.000000        0.000000
# 14       0.000000      0.000000         0.000000        0.000000
# 15       0.000000      0.000000         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.755020
# 1   {'criterion': 'squared_error', 'max_features':...           0.694556
# 2   {'criterion': 'squared_error', 'max_features':...           0.711351
# 3   {'criterion': 'squared_error', 'max_features':...           0.702835
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.598529
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.676595
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.704437
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.652177
# 8   {'criterion': 'absolute_error', 'max_features'...           0.749482
# 9   {'criterion': 'absolute_error', 'max_features'...           0.679580
# 10  {'criterion': 'absolute_error', 'max_features'...           0.662579
# 11  {'criterion': 'absolute_error', 'max_features'...           0.694744
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 14  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 15  {'criterion': 'poisson', 'max_features': 'log2...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.600444           0.774118           0.723842
# 1            0.589848           0.714365           0.668842
# 2            0.596693           0.655127           0.690761
# 3            0.559522           0.631546           0.696486
# 4            0.593628           0.764747           0.685353
# 5            0.584762           0.716010           0.678474
# 6            0.646858           0.701314           0.700025
# 7            0.560371           0.639071           0.596642
# 8            0.596975           0.673365           0.764179
# 9            0.570209           0.559153           0.699143
# 10           0.527170           0.744563           0.712312
# 11           0.583138           0.723820           0.562902
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.700507         0.710786        0.060694                1
# 1            0.704432         0.674409        0.044912                5
# 2            0.768882         0.684563        0.057364                3
# 3            0.650820         0.648242        0.051893               10
# 4            0.721695         0.672790        0.067508                7
# 5            0.648712         0.660911        0.043676                8
# 6            0.618935         0.674314        0.034981                6
# 7            0.605974         0.610847        0.032490               12
# 8            0.753654         0.707531        0.064010                2
# 9            0.641587         0.629934        0.056511               11
# 10           0.760154         0.681356        0.084010                4
# 11           0.694406         0.651802        0.065519                9
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14                NaN              NaN             NaN               13
# 15                NaN              NaN             NaN               13

# %%
y_predt=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,y_predt)
r_score
# Out:
# 0.998667156135576

# %%
import pickle
filename="final_model_DR.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 19
# BMI: 33.777
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
preinput=sd.transform([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
preinput
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.43876426,  0.51076941, -0.90861367, -1.0105187 , -0.5074631 ]])

# %%
loaded_model=pickle.load(open("final_model_DR.sav",'rb'))

# %%
result=loaded_model.predict(preinput)
result
# Out:
# array([-0.14768408])

# %%
preoutput=sdy.inverse_transform([result])
preoutput
# Out:
# array([[11482.63485]])
