# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd=StandardScaler()

# %%
X_train=sd.fit_transform(X_train)
X_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
X_test=sd.transform(X_test)
X_test
# Out:
# array([[ 0.89459283, -0.08863026, -0.06746417,  1.02378711, -0.50466988],
#        [ 0.53757957, -0.22180837, -0.06746417, -0.97676557, -0.50466988],
#        [ 0.60898222,  1.57449152,  0.76341038,  1.02378711,  1.98149332],
#        ...,
#        [ 1.10880078,  1.20785059, -0.89833872,  1.02378711, -0.50466988],
#        [ 1.75142463,  1.34905148, -0.06746417,  1.02378711, -0.50466988],
#        [ 1.60861933, -0.92299913, -0.89833872, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
param_grid={'n_estimators':[10,50,100],'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'max_features':['sqrt', 'log2']}

# %%
grid=GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3,n_jobs=-1)

# %%
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
#print best parameter after tuning
result=grid.cv_results_
print("Thte R_Score value for best parameter:{}".format(grid.best_params_))
# Out:
# Thte R_Score value for best parameter:{'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}

# %%
#Table
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.035148      0.004670         0.005801        0.004631
# 1        0.145159      0.005790         0.008429        0.004678
# 2        0.249232      0.009551         0.009135        0.001277
# 3        0.029085      0.003084         0.003345        0.003173
# 4        0.122233      0.010467         0.006414        0.002889
# 5        0.228928      0.012053         0.011657        0.002950
# 6        0.021919      0.004423         0.002018        0.004037
# 7        0.124303      0.004380         0.004135        0.003941
# 8        0.241724      0.015854         0.013767        0.002060
# 9        0.027332      0.008538         0.000402        0.000805
# 10       0.115760      0.004988         0.008591        0.001218
# 11       0.241125      0.007944         0.008107        0.005261
# 12       0.082460      0.008841         0.003557        0.003706
# 13       0.322862      0.018733         0.005019        0.003182
# 14       0.615255      0.014798         0.008264        0.004151
# 15       0.066762      0.007889         0.002716        0.003921
# 16       0.317526      0.018116         0.005209        0.002874
# 17       0.625211      0.015755         0.008372        0.001999
# 18       0.026919      0.003199         0.005023        0.004495
# 19       0.116624      0.004937         0.005743        0.004722
# 20       0.246701      0.013651         0.009984        0.006836
# 21       0.031234      0.006415         0.003562        0.005947
# 22       0.137555      0.021562         0.007653        0.002657
# 23       0.210644      0.010903         0.003944        0.004833
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                 50
# 2    squared_error               sqrt                100
# 3    squared_error               log2                 10
# 4    squared_error               log2                 50
# 5    squared_error               log2                100
# 6     friedman_mse               sqrt                 10
# 7     friedman_mse               sqrt                 50
# 8     friedman_mse               sqrt                100
# 9     friedman_mse               log2                 10
# 10    friedman_mse               log2                 50
# 11    friedman_mse               log2                100
# 12  absolute_error               sqrt                 10
# 13  absolute_error               sqrt                 50
# 14  absolute_error               sqrt                100
# 15  absolute_error               log2                 10
# 16  absolute_error               log2                 50
# 17  absolute_error               log2                100
# 18         poisson               sqrt                 10
# 19         poisson               sqrt                 50
# 20         poisson               sqrt                100
# 21         poisson               log2                 10
# 22         poisson               log2                 50
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.846410
# 1   {'criterion': 'squared_error', 'max_features':...           0.859631
# 2   {'criterion': 'squared_error', 'max_features':...           0.866163
# 3   {'criterion': 'squared_error', 'max_features':...           0.844042
# 4   {'criterion': 'squared_error', 'max_features':...           0.860352
# 5   {'criterion': 'squared_error', 'max_features':...           0.861436
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.835173
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.865439
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.862881
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.829349
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.864682
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.864068
# 12  {'criterion': 'absolute_error', 'max_features'...           0.858989
# 13  {'criterion': 'absolute_error', 'max_features'...           0.850674
# 14  {'criterion': 'absolute_error', 'max_features'...           0.860143
# 15  {'criterion': 'absolute_error', 'max_features'...           0.831482
# 16  {'criterion': 'absolute_error', 'max_features'...           0.856988
# 17  {'criterion': 'absolute_error', 'max_features'...           0.856680
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.832954
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.856231
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.860791
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.847615
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.859136
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.868816
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.764818           0.790905           0.815744
# 1            0.792050           0.799820           0.820379
# 2            0.789424           0.811837           0.825477
# 3            0.776569           0.794024           0.788445
# 4            0.785756           0.814866           0.821516
# 5            0.798132           0.807119           0.828978
# 6            0.753355           0.800287           0.784532
# 7            0.788790           0.808272           0.818932
# 8            0.792548           0.809661           0.821396
# 9            0.770778           0.785322           0.802922
# 10           0.787534           0.802398           0.830027
# 11           0.787417           0.813473           0.826221
# 12           0.780983           0.806664           0.811628
# 13           0.786684           0.807186           0.822047
# 14           0.797157           0.810097           0.823503
# 15           0.765290           0.808655           0.801710
# 16           0.800655           0.816431           0.817392
# 17           0.796812           0.806076           0.826403
# 18           0.747952           0.733526           0.808219
# 19           0.791408           0.809938           0.825407
# 20           0.787560           0.806780           0.826361
# 21           0.775644           0.791238           0.817679
# 22           0.789033           0.809781           0.823483
# 23           0.786990           0.807874           0.827566
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.761760         0.795928        0.031943               18
# 1            0.765724         0.807521        0.031389               15
# 2            0.773295         0.813239        0.031985                2
# 3            0.738556         0.788327        0.033918               22
# 4            0.767457         0.809989        0.031904               13
# 5            0.772680         0.813669        0.029935                1
# 6            0.757699         0.786209        0.029969               23
# 7            0.776276         0.811542        0.030762               10
# 8            0.777193         0.812736        0.029223                4
# 9            0.756788         0.789032        0.025318               21
# 10           0.758764         0.808681        0.036250               14
# 11           0.769920         0.812220        0.032528                6
# 12           0.748644         0.801382        0.036466               17
# 13           0.758920         0.805102        0.031114               16
# 14           0.772384         0.812657        0.029125                5
# 15           0.762306         0.793889        0.026487               20
# 16           0.768148         0.811923        0.028720                7
# 17           0.771870         0.811568        0.028562                9
# 18           0.751903         0.774911        0.038593               24
# 19           0.776474         0.811892        0.027664                8
# 20           0.771373         0.810573        0.031151               12
# 21           0.737525         0.793940        0.037334               19
# 22           0.772088         0.810704        0.029902               11
# 23           0.774486         0.813147        0.033207                3

# %%
y_predt=grid.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,y_predt)
r_score
# Out:
# 0.8703368551676693
