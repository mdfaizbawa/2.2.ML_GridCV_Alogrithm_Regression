# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
independent=sd.fit_transform(independent)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd=StandardScaler()
independent=sd.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LinearRegression

# %%
param_grid={'fit_intercept':[True,False],'copy_X':[True,False],'positive':[False,True]}

# %%
grid=GridSearchCV(LinearRegression(), param_grid, refit=True, verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=LinearRegression(), n_jobs=-1,
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True]},
#              verbose=3)

# %%
#print best parameter after tuning
result=grid.cv_results_
print("Thte R_Score value for best parameter:{}".format(grid.best_params_))
# Out:
# Thte R_Score value for best parameter:{'copy_X': True, 'fit_intercept': True, 'positive': True}

# %%
#Table
table=pd.DataFrame.from_dict(result)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_copy_X  \
# 0       0.044006      0.024682         0.001785        0.000533         True
# 1       0.028831      0.014680         0.002929        0.000166         True
# 2       0.009423      0.011907         0.001006        0.002012         True
# 3       0.002004      0.004008         0.002514        0.003881         True
# 4       0.004666      0.002766         0.001132        0.000993        False
# 5       0.004452      0.003040         0.001202        0.002405        False
# 6       0.001558      0.002693         0.000000        0.000000        False
# 7       0.005409      0.004416         0.000641        0.000524        False
#
#   param_fit_intercept param_positive  \
# 0                True          False
# 1                True           True
# 2               False          False
# 3               False           True
# 4                True          False
# 5                True           True
# 6               False          False
# 7               False           True
#
#                                               params  split0_test_score  \
# 0  {'copy_X': True, 'fit_intercept': True, 'posit...           0.760979
# 1  {'copy_X': True, 'fit_intercept': True, 'posit...           0.761482
# 2  {'copy_X': True, 'fit_intercept': False, 'posi...          -0.329893
# 3  {'copy_X': True, 'fit_intercept': False, 'posi...          -0.329938
# 4  {'copy_X': False, 'fit_intercept': True, 'posi...           0.760979
# 5  {'copy_X': False, 'fit_intercept': True, 'posi...           0.761482
# 6  {'copy_X': False, 'fit_intercept': False, 'pos...          -0.329893
# 7  {'copy_X': False, 'fit_intercept': False, 'pos...          -0.329938
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.708733           0.775584           0.731367           0.756545
# 1           0.708782           0.775584           0.731353           0.756751
# 2          -0.724411          -0.390302          -0.468261          -0.473329
# 3          -0.716615          -0.390302          -0.463066          -0.473329
# 4           0.708733           0.775584           0.731367           0.756545
# 5           0.708782           0.775584           0.731353           0.756751
# 6          -0.724411          -0.390302          -0.468261          -0.473329
# 7          -0.716615          -0.390302          -0.463066          -0.473329
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.746642        0.023713                3
# 1         0.746790        0.023778                1
# 2        -0.477239        0.134506                7
# 3        -0.474650        0.131711                5
# 4         0.746642        0.023713                3
# 5         0.746790        0.023778                1
# 6        -0.477239        0.134506                7
# 7        -0.474650        0.131711                5

# %%
y_predt=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,y_predt)
r_score
# Out:
# 0.749694530346479
