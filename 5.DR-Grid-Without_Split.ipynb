# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
independent=sd.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'splitter':['best', 'random'],'max_features':['sqrt', 'log2']}

# %%
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best parameter after tuning
resul=grid.cv_results_
print("Thte R_Score value for best parameter:{}".format(grid.best_params_))
# Out:
# Thte R_Score value for best parameter:{'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
#Table
table=pd.DataFrame.from_dict(resul)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004839      0.002946         0.003125        0.003731
# 1        0.007805      0.003147         0.000605        0.001210
# 2        0.005277      0.004545         0.000000        0.000000
# 3        0.004669      0.003061         0.002544        0.000771
# 4        0.004664      0.001012         0.001714        0.000611
# 5        0.003426      0.000845         0.001924        0.000155
# 6        0.002495      0.001599         0.000000        0.000000
# 7        0.005120      0.006344         0.002003        0.004006
# 8        0.017297      0.003299         0.001410        0.001461
# 9        0.012530      0.000961         0.000302        0.000604
# 10       0.017661      0.003030         0.003382        0.004150
# 11       0.012727      0.003289         0.002218        0.003006
# 12       0.004637      0.003286         0.000400        0.000800
# 13       0.001207      0.001478         0.000000        0.000000
# 14       0.005873      0.004814         0.004299        0.004814
# 15       0.002264      0.003979         0.003317        0.002708
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.675600
# 1   {'criterion': 'squared_error', 'max_features':...           0.672275
# 2   {'criterion': 'squared_error', 'max_features':...           0.748160
# 3   {'criterion': 'squared_error', 'max_features':...           0.699291
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.711853
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.691000
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.688152
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.723545
# 8   {'criterion': 'absolute_error', 'max_features'...           0.730658
# 9   {'criterion': 'absolute_error', 'max_features'...           0.649102
# 10  {'criterion': 'absolute_error', 'max_features'...           0.632576
# 11  {'criterion': 'absolute_error', 'max_features'...           0.696121
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.695725
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.676205
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.716948
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.522252
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.602727           0.731178           0.723540
# 1            0.483345           0.644312           0.608680
# 2            0.611701           0.728502           0.668832
# 3            0.534889           0.764030           0.652691
# 4            0.693873           0.689784           0.693796
# 5            0.588986           0.556795           0.636257
# 6            0.623768           0.563221           0.761968
# 7            0.587638           0.543578           0.683467
# 8            0.649493           0.729430           0.746467
# 9            0.652830           0.738947           0.667536
# 10           0.590851           0.700054           0.546011
# 11           0.373064           0.682155           0.737667
# 12           0.643037           0.676235           0.760104
# 13           0.576944           0.625551           0.706541
# 14           0.645366           0.732744           0.698136
# 15           0.634620           0.628735           0.695576
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.662887         0.679186        0.046465                6
# 1            0.585491         0.598821        0.064922               16
# 2            0.703556         0.692150        0.048175                5
# 3            0.659206         0.662021        0.074903                9
# 4            0.725868         0.703035        0.013740                4
# 5            0.635122         0.621632        0.045776               15
# 6            0.719275         0.671277        0.070352                8
# 7            0.609194         0.629484        0.065275               13
# 8            0.752820         0.721774        0.037244                1
# 9            0.678796         0.677442        0.032532                7
# 10           0.651955         0.624290        0.052574               14
# 11           0.736180         0.645037        0.137727               11
# 12           0.759394         0.706899        0.046325                3
# 13           0.671009         0.651250        0.045281               10
# 14           0.754777         0.709594        0.037116                2
# 15           0.697961         0.635829        0.063846               12

# %%
y_predt=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,y_predt)
r_score
# Out:
# 0.9915693190587075

# %%
import pickle
filename="final_model_DR.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 19
# BMI: 33.777
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
preinput=sd.transform([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
preinput
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.43876426,  0.51076941, -0.90861367, -1.0105187 , -0.5074631 ]])

# %%
loaded_model=pickle.load(open("final_model_DR.sav",'rb'))

# %%
result=loaded_model.predict(preinput)
result
# Out:
# array([2134.9015])
